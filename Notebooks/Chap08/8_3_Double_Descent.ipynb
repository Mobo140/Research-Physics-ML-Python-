# %% [markdown]
# <a href="https://colab.research.google.com/github/Mobo140/Research-Physics-ML-Python-/blob/master/Notebooks/Chap08/8_3_Double_Descent.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Notebook 8.3: Double Descent**
#
# This notebook investigates double descent as described in section 8.4 of the book.
#
# It uses the MNIST-1D database which can be found at https://github.com/greydanus/mnist1d
#
# Work through the cells below, running each cell in turn. In various places you will see the words "TODO". Follow the instructions at these places and make predictions about what is going to happen or write code to complete the functions.
#
# Contact me at udlbookmail@gmail.com if you find any mistakes or have any suggestions.

# %%
# Run this if you're in a Colab to install MNIST 1D repository
# !pip install git+https://github.com/greydanus/mnist1d
# Out:
# Collecting git+https://github.com/greydanus/mnist1d
#   Cloning https://github.com/greydanus/mnist1d to /tmp/pip-req-build-r2m8dn7v
#   Running command git clone --filter=blob:none --quiet https://github.com/greydanus/mnist1d /tmp/pip-req-build-r2m8dn7v
#   Resolved https://github.com/greydanus/mnist1d to commit 7878d96082abd200c546a07a4101fa90b30fdf7e
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (2.32.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (2.0.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (3.10.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (1.16.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (2.9.0.post0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (2025.10.5)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib->mnist1d==0.0.2.post16) (1.17.0)
# Building wheels for collected packages: mnist1d
#   Building wheel for mnist1d (pyproject.toml) ... done
#   Created wheel for mnist1d: filename=mnist1d-0.0.2.post16-py3-none-any.whl size=14665 sha256=d7f46cb3eb2a8ec67cc94634949ad49eba283bbfad318520462a03c8b86cb0fe
#   Stored in directory: /tmp/pip-ephem-wheel-cache-wq75x28m/wheels/18/40/b6/29381fee9b4c80fdbc304d52bb065a7286bbcca5ca2b8737c0
# Successfully built mnist1d
# Installing collected packages: mnist1d
# Successfully installed mnist1d-0.0.2.post16

# %%
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import numpy as np
import matplotlib.pyplot as plt
import mnist1d
import random
random.seed(0)

# Try attaching to GPU -- Use "Change Runtime Type to change to GPUT"
DEVICE = str(torch.device('cuda' if torch.cuda.is_available() else 'cpu'))
print('Using:', DEVICE)
# Out:
# Using: cuda

# %%
args = mnist1d.data.get_dataset_args()
args.num_samples = 8000
args.train_split = 0.5
args.corr_noise_scale = 0.25
args.iid_noise_scale=2e-2
data = mnist1d.data.get_dataset(args, path='./mnist1d_data.pkl', download=False, regenerate=True)

# Add 15% noise to training labels
for c_y in range(len(data['y'])):
    random_number = random.random()
    if random_number < 0.15 :
        random_int = int(random.random() * 10)
        data['y'][c_y] = random_int

# The training and test input and outputs are in
# data['x'], data['y'], data['x_test'], and data['y_test']
print("Examples in training set: {}".format(len(data['y'])))
print("Examples in test set: {}".format(len(data['y_test'])))
print("Dimensionality of each example: {}".format(data['x'].shape[-1]))
# Out:
# Did or could not load data from ./mnist1d_data.pkl. Rebuilding dataset...
# Examples in training set: 4000
# Examples in test set: 4000
# Dimensionality of each example: 40

# %%
# Initialize the parameters with He initialization
def weights_init(layer_in):
  if isinstance(layer_in, nn.Linear):
    nn.init.kaiming_uniform_(layer_in.weight)
    layer_in.bias.data.fill_(0.0)

# Return an initialized model with two hidden layers and n_hidden hidden units at each
def get_model(n_hidden):

  D_i = 40    # Input dimensions
  D_k = n_hidden   # Hidden dimensions
  D_o = 10    # Output dimensions

  # Define a model with two hidden layers
  # And ReLU activations between them
  model = nn.Sequential(
  nn.Linear(D_i, D_k),
  nn.ReLU(),
  nn.Linear(D_k, D_k),
  nn.ReLU(),
  nn.Linear(D_k, D_o))

  # Call the function you just defined
  model.apply(weights_init)

  # Return the model
  return model ;

# %%
def fit_model(model, data, n_epoch):

  # choose cross entropy loss function (equation 5.24)
  loss_function = torch.nn.CrossEntropyLoss()
  # construct SGD optimizer and initialize learning rate and momentum
  # optimizer = torch.optim.Adam(model.parameters(), lr=0.01)
  optimizer = torch.optim.SGD(model.parameters(), lr = 0.01, momentum=0.9)

  x_train = torch.tensor(data['x'].astype('float32'))
  y_train = torch.tensor(data['y'].transpose().astype('long'))
  x_test= torch.tensor(data['x_test'].astype('float32'))
  y_test = torch.tensor(data['y_test'].astype('long'))

  # load the data into a class that creates the batches
  data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

  for epoch in range(n_epoch):
    # loop over batches
    for i, batch in enumerate(data_loader):
      # retrieve inputs and labels for this batch
      x_batch, y_batch = batch
      # zero the parameter gradients
      optimizer.zero_grad()
      # forward pass -- calculate model output
      pred = model(x_batch)
      # compute the loss
      loss = loss_function(pred, y_batch)
      # backward pass
      loss.backward()
      # SGD update
      optimizer.step()

    # Run whole dataset to get statistics -- normally wouldn't do this
    pred_train = model(x_train)
    pred_test = model(x_test)
    _, predicted_train_class = torch.max(pred_train.data, 1)
    _, predicted_test_class = torch.max(pred_test.data, 1)
    errors_train = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
    errors_test= 100 - 100 * (predicted_test_class == y_test).float().sum() / len(y_test)
    losses_train = loss_function(pred_train, y_train).item()
    losses_test= loss_function(pred_test, y_test).item()
    if epoch%100 ==0 :
      print(f'Epoch {epoch:5d}, train loss {losses_train:.6f}, train error {errors_train:3.2f},  test loss {losses_test:.6f}, test error {errors_test:3.2f}')

  return errors_train, errors_test

# %%
def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

# %% [markdown]
# The following code produces the double descent curve by training the model with different numbers of hidden units and plotting the test error.
#
# TODO:
#
# *Before* you run the code, and considering that there are 4000 training examples predict:<br>
#
# 1.    At what capacity do you think the training error will become zero?
# 2.   At what capacity do you expect the first minima of the double descent curve to appear?
# 3. At what capacity do you expect the maximum of the double descent curve to appear?

# %%
# This code will take a while (~30 mins on GPU) to run!  Go and make a cup of coffee!

hidden_variables = np.array([2,4,6,8,10,14,18,22,26,30,35,40,45,50,55,60,70,80,90,100,120,140,160,180,200,250,300,400]) ;

errors_train_all = np.zeros_like(hidden_variables)
errors_test_all = np.zeros_like(hidden_variables)
total_weights_all = np.zeros_like(hidden_variables)

# loop over the dataset n_epoch times
n_epoch = 1000

# For each hidden variable size
for c_hidden in range(len(hidden_variables)):
    print(f'Training model with {hidden_variables[c_hidden]:3d} hidden variables')
    # Get a model
    model = get_model(hidden_variables[c_hidden]) ;
    # Count and store number of weights
    total_weights_all[c_hidden] = count_parameters(model)
    # Train the model
    errors_train, errors_test = fit_model(model, data, n_epoch)
    # Store the results
    errors_train_all[c_hidden] = errors_train
    errors_test_all[c_hidden]= errors_test
# Out:
# Training model with   2 hidden variables
# Epoch     0, train loss 2.304058, train error 89.00,  test loss 2.306129, test error 89.22
# Epoch   100, train loss 1.928874, train error 72.30,  test loss 1.793868, test error 70.35
# Epoch   200, train loss 1.910207, train error 72.15,  test loss 1.747988, test error 70.70
# Epoch   300, train loss 1.904717, train error 71.75,  test loss 1.749511, test error 70.07
# Epoch   400, train loss 1.901146, train error 71.22,  test loss 1.754134, test error 70.20
# Epoch   500, train loss 1.901130, train error 70.95,  test loss 1.755309, test error 70.80
# Epoch   600, train loss 1.899752, train error 70.97,  test loss 1.751925, test error 70.30
# Epoch   700, train loss 1.898252, train error 71.00,  test loss 1.750137, test error 68.60
# Epoch   800, train loss 1.895879, train error 70.07,  test loss 1.766744, test error 68.80
# Epoch   900, train loss 1.895909, train error 71.12,  test loss 1.775741, test error 69.70
# Training model with   4 hidden variables
# Epoch     0, train loss 2.297382, train error 88.80,  test loss 2.298187, test error 88.65
# Epoch   100, train loss 1.847957, train error 67.78,  test loss 1.729583, test error 66.15
# Epoch   200, train loss 1.829999, train error 67.18,  test loss 1.730950, test error 66.80
# Epoch   300, train loss 1.823606, train error 67.03,  test loss 1.722137, test error 66.60
# Epoch   400, train loss 1.823847, train error 67.72,  test loss 1.710747, test error 66.35
# Epoch   500, train loss 1.816873, train error 66.05,  test loss 1.708966, test error 65.18
# Epoch   600, train loss 1.817914, train error 66.53,  test loss 1.710325, test error 65.65
# Epoch   700, train loss 1.816417, train error 66.60,  test loss 1.712720, test error 65.40
# Epoch   800, train loss 1.814657, train error 65.90,  test loss 1.682469, test error 63.67
# Epoch   900, train loss 1.801631, train error 64.20,  test loss 1.652997, test error 61.88
# Training model with   6 hidden variables
# Epoch     0, train loss 2.312511, train error 89.07,  test loss 2.309469, test error 89.25
# Epoch   100, train loss 1.740289, train error 63.70,  test loss 1.587777, test error 62.33
# Epoch   200, train loss 1.699582, train error 62.17,  test loss 1.558150, test error 61.28
# Epoch   300, train loss 1.682258, train error 61.17,  test loss 1.546302, test error 59.83
# Epoch   400, train loss 1.670585, train error 60.35,  test loss 1.559192, test error 59.45
# Epoch   500, train loss 1.661031, train error 60.28,  test loss 1.561325, test error 58.85
# Epoch   600, train loss 1.654891, train error 59.97,  test loss 1.565556, test error 58.97
# Epoch   700, train loss 1.648433, train error 59.78,  test loss 1.589482, test error 59.75
# Epoch   800, train loss 1.647997, train error 59.58,  test loss 1.601886, test error 59.55
# Epoch   900, train loss 1.648700, train error 60.40,  test loss 1.606560, test error 60.33
# Training model with   8 hidden variables
# Epoch     0, train loss 2.242530, train error 80.62,  test loss 2.223342, test error 80.05
# Epoch   100, train loss 1.532417, train error 52.08,  test loss 1.347415, test error 50.35
# Epoch   200, train loss 1.484107, train error 50.85,  test loss 1.307694, test error 49.25
# Epoch   300, train loss 1.465795, train error 49.78,  test loss 1.309055, test error 48.72
# Epoch   400, train loss 1.456924, train error 49.53,  test loss 1.302088, test error 48.75
# Epoch   500, train loss 1.454651, train error 49.67,  test loss 1.297266, test error 48.58
# Epoch   600, train loss 1.450115, train error 49.30,  test loss 1.301384, test error 49.83
# Epoch   700, train loss 1.452889, train error 49.00,  test loss 1.297841, test error 48.80
# Epoch   800, train loss 1.448817, train error 49.30,  test loss 1.293629, test error 49.00
# Epoch   900, train loss 1.448728, train error 50.20,  test loss 1.291953, test error 48.58
# Training model with  10 hidden variables
# Epoch     0, train loss 2.195343, train error 82.75,  test loss 2.182116, test error 82.05
# Epoch   100, train loss 1.484854, train error 50.08,  test loss 1.318494, test error 49.60
# Epoch   200, train loss 1.425419, train error 47.85,  test loss 1.262553, test error 47.58
# Epoch   300, train loss 1.402965, train error 47.60,  test loss 1.258552, test error 47.00
# Epoch   400, train loss 1.395125, train error 46.88,  test loss 1.270593, test error 47.25
# Epoch   500, train loss 1.386656, train error 47.50,  test loss 1.270018, test error 47.70
# Epoch   600, train loss 1.389212, train error 47.17,  test loss 1.266292, test error 47.20
# Epoch   700, train loss 1.376802, train error 47.08,  test loss 1.279219, test error 47.47
# Epoch   800, train loss 1.384623, train error 47.72,  test loss 1.283292, test error 48.00
# Epoch   900, train loss 1.373396, train error 47.50,  test loss 1.297539, test error 47.92
# Training model with  14 hidden variables
# Epoch     0, train loss 2.229764, train error 83.75,  test loss 2.233359, test error 84.45
# Epoch   100, train loss 1.452278, train error 48.92,  test loss 1.383231, test error 52.83
# Epoch   200, train loss 1.357713, train error 45.58,  test loss 1.341521, test error 50.28
# Epoch   300, train loss 1.317300, train error 44.20,  test loss 1.331014, test error 48.67
# Epoch   400, train loss 1.290869, train error 43.38,  test loss 1.357416, test error 49.80
# Epoch   500, train loss 1.279190, train error 43.30,  test loss 1.365735, test error 49.80
# Epoch   600, train loss 1.263966, train error 42.72,  test loss 1.380423, test error 50.92
# Epoch   700, train loss 1.265882, train error 42.25,  test loss 1.397345, test error 51.40
# Epoch   800, train loss 1.253272, train error 42.33,  test loss 1.397981, test error 51.08
# Epoch   900, train loss 1.250713, train error 41.80,  test loss 1.414582, test error 51.28
# Training model with  18 hidden variables
# Epoch     0, train loss 2.290994, train error 83.80,  test loss 2.285319, test error 84.75
# Epoch   100, train loss 1.331238, train error 43.85,  test loss 1.247087, test error 45.85
# Epoch   200, train loss 1.240923, train error 41.60,  test loss 1.269870, test error 46.55
# Epoch   300, train loss 1.203948, train error 40.38,  test loss 1.325702, test error 48.05
# Epoch   400, train loss 1.169245, train error 39.75,  test loss 1.361619, test error 49.97
# Epoch   500, train loss 1.150041, train error 38.55,  test loss 1.398745, test error 49.70
# Epoch   600, train loss 1.137319, train error 38.33,  test loss 1.426359, test error 50.28
# Epoch   700, train loss 1.134882, train error 39.20,  test loss 1.470999, test error 51.22
# Epoch   800, train loss 1.125453, train error 38.38,  test loss 1.477541, test error 50.62
# Epoch   900, train loss 1.123026, train error 38.47,  test loss 1.490814, test error 51.08
# Training model with  22 hidden variables
# Epoch     0, train loss 2.195264, train error 80.00,  test loss 2.178782, test error 80.55
# Epoch   100, train loss 1.234831, train error 41.38,  test loss 1.302331, test error 47.97
# Epoch   200, train loss 1.151411, train error 39.12,  test loss 1.417000, test error 50.53
# Epoch   300, train loss 1.066596, train error 36.10,  test loss 1.454107, test error 49.72
# Epoch   400, train loss 1.038185, train error 35.50,  test loss 1.533945, test error 51.33
# Epoch   500, train loss 1.018665, train error 34.75,  test loss 1.618070, test error 51.30
# Epoch   600, train loss 0.997202, train error 33.93,  test loss 1.652844, test error 51.28
# Epoch   700, train loss 0.993260, train error 34.25,  test loss 1.714848, test error 52.30
# Epoch   800, train loss 0.986900, train error 33.90,  test loss 1.744722, test error 52.03
# Epoch   900, train loss 0.968182, train error 33.32,  test loss 1.802752, test error 52.33
# Training model with  26 hidden variables
# Epoch     0, train loss 2.130528, train error 78.28,  test loss 2.098861, test error 77.75
# Epoch   100, train loss 1.200077, train error 39.62,  test loss 1.312283, test error 49.80
# Epoch   200, train loss 1.051561, train error 35.47,  test loss 1.420655, test error 49.95
# Epoch   300, train loss 0.975591, train error 33.20,  test loss 1.531848, test error 49.80
# Epoch   400, train loss 0.933480, train error 31.78,  test loss 1.630959, test error 51.65
# Epoch   500, train loss 0.907835, train error 31.32,  test loss 1.741680, test error 52.05
# Epoch   600, train loss 0.871998, train error 29.40,  test loss 1.829283, test error 53.00
# Epoch   700, train loss 0.878804, train error 30.22,  test loss 1.926556, test error 53.58
# Epoch   800, train loss 0.855916, train error 29.78,  test loss 1.994524, test error 53.08
# Epoch   900, train loss 0.842563, train error 28.65,  test loss 2.093656, test error 54.50
# Training model with  30 hidden variables
# Epoch     0, train loss 2.155278, train error 80.53,  test loss 2.128660, test error 80.30
# Epoch   100, train loss 1.117060, train error 36.20,  test loss 1.375914, test error 49.17
# Epoch   200, train loss 0.936478, train error 30.05,  test loss 1.579714, test error 50.45
# Epoch   300, train loss 0.850570, train error 27.38,  test loss 1.793566, test error 52.95
# Epoch   400, train loss 0.828832, train error 27.80,  test loss 1.983056, test error 53.50
# Epoch   500, train loss 0.765827, train error 25.82,  test loss 2.095538, test error 53.75
# Epoch   600, train loss 0.730653, train error 24.50,  test loss 2.261464, test error 53.50
# Epoch   700, train loss 0.716214, train error 24.25,  test loss 2.471972, test error 54.75
# Epoch   800, train loss 0.693372, train error 23.93,  test loss 2.604016, test error 54.95
# Epoch   900, train loss 0.696353, train error 24.12,  test loss 2.746573, test error 54.50
# Training model with  35 hidden variables
# Epoch     0, train loss 2.135127, train error 78.70,  test loss 2.133283, test error 79.53
# Epoch   100, train loss 1.047381, train error 34.95,  test loss 1.419935, test error 51.88
# Epoch   200, train loss 0.814090, train error 26.97,  test loss 1.681335, test error 52.97
# Epoch   300, train loss 0.710520, train error 25.07,  test loss 1.990480, test error 53.45
# Epoch   400, train loss 0.640852, train error 22.35,  test loss 2.356533, test error 56.45
# Epoch   500, train loss 0.573344, train error 20.35,  test loss 2.627444, test error 55.00
# Epoch   600, train loss 0.547094, train error 19.90,  test loss 2.956710, test error 56.05
# Epoch   700, train loss 0.549487, train error 19.62,  test loss 3.288423, test error 56.03
# Epoch   800, train loss 0.519763, train error 20.12,  test loss 3.670833, test error 58.53
# Epoch   900, train loss 0.477196, train error 17.68,  test loss 3.885925, test error 56.75
# Training model with  40 hidden variables
# Epoch     0, train loss 2.149919, train error 80.38,  test loss 2.137983, test error 80.47
# Epoch   100, train loss 0.932064, train error 30.30,  test loss 1.486388, test error 50.55
# Epoch   200, train loss 0.657766, train error 22.57,  test loss 1.951201, test error 53.10
# Epoch   300, train loss 0.493350, train error 16.88,  test loss 2.517680, test error 54.38
# Epoch   400, train loss 0.403717, train error 13.82,  test loss 3.184345, test error 55.15
# Epoch   500, train loss 0.363943, train error 11.90,  test loss 3.923914, test error 56.78
# Epoch   600, train loss 0.318097, train error 11.00,  test loss 4.568000, test error 56.25
# Epoch   700, train loss 0.288144, train error 10.50,  test loss 5.264020, test error 56.35
# Epoch   800, train loss 0.238725, train error 8.18,  test loss 6.020105, test error 57.20
# Epoch   900, train loss 0.254470, train error 9.32,  test loss 6.535719, test error 57.72
# Training model with  45 hidden variables
# Epoch     0, train loss 2.091832, train error 76.85,  test loss 2.035650, test error 76.15
# Epoch   100, train loss 0.809181, train error 25.53,  test loss 1.531053, test error 50.70
# Epoch   200, train loss 0.466825, train error 14.60,  test loss 2.350702, test error 53.55
# Epoch   300, train loss 0.252518, train error 6.43,  test loss 3.471284, test error 55.05
# Epoch   400, train loss 0.191863, train error 5.30,  test loss 4.872974, test error 56.17
# Epoch   500, train loss 0.196354, train error 6.38,  test loss 6.233309, test error 57.45
# Epoch   600, train loss 0.125487, train error 3.97,  test loss 7.437951, test error 56.70
# Epoch   700, train loss 0.011613, train error 0.00,  test loss 8.456940, test error 57.38
# Epoch   800, train loss 0.007697, train error 0.00,  test loss 9.141736, test error 57.47
# Epoch   900, train loss 0.005817, train error 0.00,  test loss 9.646293, test error 57.50
# Training model with  50 hidden variables
# Epoch     0, train loss 2.063369, train error 76.97,  test loss 2.016064, test error 75.60
# Epoch   100, train loss 0.723353, train error 23.62,  test loss 1.575777, test error 51.10
# Epoch   200, train loss 0.323790, train error 9.57,  test loss 2.646215, test error 53.22
# Epoch   300, train loss 0.141578, train error 3.28,  test loss 4.352223, test error 55.60
# Epoch   400, train loss 0.026812, train error 0.00,  test loss 5.889760, test error 56.03
# Epoch   500, train loss 0.012482, train error 0.00,  test loss 6.856531, test error 56.17
# Epoch   600, train loss 0.007937, train error 0.00,  test loss 7.483822, test error 55.88
# Epoch   700, train loss 0.005674, train error 0.00,  test loss 7.951826, test error 55.72
# Epoch   800, train loss 0.004434, train error 0.00,  test loss 8.325540, test error 55.97
# Epoch   900, train loss 0.003551, train error 0.00,  test loss 8.639319, test error 55.85
# Training model with  55 hidden variables
# Epoch     0, train loss 2.088788, train error 77.72,  test loss 2.034075, test error 76.97
# Epoch   100, train loss 0.677543, train error 21.72,  test loss 1.534421, test error 50.78
# Epoch   200, train loss 0.238239, train error 5.95,  test loss 2.715931, test error 51.97
# Epoch   300, train loss 0.045823, train error 0.05,  test loss 4.317653, test error 52.70
# Epoch   400, train loss 0.015968, train error 0.00,  test loss 5.340799, test error 53.38
# Epoch   500, train loss 0.009085, train error 0.00,  test loss 5.948762, test error 53.30
# Epoch   600, train loss 0.006242, train error 0.00,  test loss 6.393900, test error 53.25
# Epoch   700, train loss 0.004676, train error 0.00,  test loss 6.734310, test error 53.33
# Epoch   800, train loss 0.003672, train error 0.00,  test loss 7.007301, test error 53.25
# Epoch   900, train loss 0.003011, train error 0.00,  test loss 7.236382, test error 53.25
# Training model with  60 hidden variables
# Epoch     0, train loss 2.048910, train error 76.45,  test loss 1.979101, test error 75.90
# Epoch   100, train loss 0.533692, train error 14.82,  test loss 1.667750, test error 50.70
# Epoch   200, train loss 0.100665, train error 0.75,  test loss 3.308691, test error 54.53
# Epoch   300, train loss 0.020190, train error 0.00,  test loss 4.609694, test error 55.42
# Epoch   400, train loss 0.009498, train error 0.00,  test loss 5.288256, test error 55.35
# Epoch   500, train loss 0.006038, train error 0.00,  test loss 5.727572, test error 55.45
# Epoch   600, train loss 0.004331, train error 0.00,  test loss 6.062612, test error 55.72
# Epoch   700, train loss 0.003309, train error 0.00,  test loss 6.321679, test error 55.58
# Epoch   800, train loss 0.002660, train error 0.00,  test loss 6.538117, test error 55.53
# Epoch   900, train loss 0.002211, train error 0.00,  test loss 6.720197, test error 55.60
# Training model with  70 hidden variables
# Epoch     0, train loss 2.050231, train error 77.20,  test loss 1.965986, test error 75.22
# Epoch   100, train loss 0.378033, train error 9.90,  test loss 1.898978, test error 52.05
# Epoch   200, train loss 0.034986, train error 0.00,  test loss 3.561123, test error 54.38
# Epoch   300, train loss 0.011460, train error 0.00,  test loss 4.383167, test error 54.97
# Epoch   400, train loss 0.006360, train error 0.00,  test loss 4.848469, test error 54.92
# Epoch   500, train loss 0.004238, train error 0.00,  test loss 5.169196, test error 55.00
# Epoch   600, train loss 0.003122, train error 0.00,  test loss 5.414177, test error 55.03
# Epoch   700, train loss 0.002446, train error 0.00,  test loss 5.612972, test error 55.05
# Epoch   800, train loss 0.001996, train error 0.00,  test loss 5.773124, test error 55.08
# Epoch   900, train loss 0.001673, train error 0.00,  test loss 5.916107, test error 55.03
# Training model with  80 hidden variables
# Epoch     0, train loss 2.076077, train error 77.60,  test loss 2.028635, test error 77.53
# Epoch   100, train loss 0.213257, train error 2.78,  test loss 2.086215, test error 51.67
# Epoch   200, train loss 0.019866, train error 0.00,  test loss 3.386937, test error 53.17
# Epoch   300, train loss 0.008107, train error 0.00,  test loss 3.929252, test error 53.38
# Epoch   400, train loss 0.004796, train error 0.00,  test loss 4.259543, test error 53.30
# Epoch   500, train loss 0.003306, train error 0.00,  test loss 4.486666, test error 53.28
# Epoch   600, train loss 0.002486, train error 0.00,  test loss 4.663011, test error 53.22
# Epoch   700, train loss 0.001971, train error 0.00,  test loss 4.805642, test error 53.15
# Epoch   800, train loss 0.001621, train error 0.00,  test loss 4.929911, test error 53.15
# Epoch   900, train loss 0.001370, train error 0.00,  test loss 5.034521, test error 53.22
# Training model with  90 hidden variables
# Epoch     0, train loss 2.015398, train error 75.40,  test loss 1.950882, test error 77.03
# Epoch   100, train loss 0.138967, train error 0.82,  test loss 2.150897, test error 50.33
# Epoch   200, train loss 0.014812, train error 0.00,  test loss 3.209960, test error 50.95
# Epoch   300, train loss 0.006509, train error 0.00,  test loss 3.645285, test error 51.38
# Epoch   400, train loss 0.003965, train error 0.00,  test loss 3.906945, test error 51.42
# Epoch   500, train loss 0.002786, train error 0.00,  test loss 4.098963, test error 51.60
# Epoch   600, train loss 0.002117, train error 0.00,  test loss 4.247047, test error 51.67
# Epoch   700, train loss 0.001690, train error 0.00,  test loss 4.371521, test error 51.83
# Epoch   800, train loss 0.001398, train error 0.00,  test loss 4.474026, test error 51.90
# Epoch   900, train loss 0.001187, train error 0.00,  test loss 4.563926, test error 51.78
# Training model with 100 hidden variables
# Epoch     0, train loss 1.990309, train error 74.25,  test loss 1.904965, test error 73.03
# Epoch   100, train loss 0.079163, train error 0.10,  test loss 2.243822, test error 50.67
# Epoch   200, train loss 0.011544, train error 0.00,  test loss 3.029310, test error 50.72
# Epoch   300, train loss 0.005451, train error 0.00,  test loss 3.376109, test error 50.78
# Epoch   400, train loss 0.003416, train error 0.00,  test loss 3.598511, test error 50.88
# Epoch   500, train loss 0.002431, train error 0.00,  test loss 3.756154, test error 50.75
# Epoch   600, train loss 0.001865, train error 0.00,  test loss 3.882897, test error 50.80
# Epoch   700, train loss 0.001501, train error 0.00,  test loss 3.988155, test error 51.10
# Epoch   800, train loss 0.001248, train error 0.00,  test loss 4.076610, test error 51.10
# Epoch   900, train loss 0.001064, train error 0.00,  test loss 4.154413, test error 51.08
# Training model with 120 hidden variables
# Epoch     0, train loss 1.962483, train error 73.03,  test loss 1.909665, test error 72.28
# Epoch   100, train loss 0.045957, train error 0.00,  test loss 2.195814, test error 49.28
# Epoch   200, train loss 0.009038, train error 0.00,  test loss 2.798531, test error 49.85
# Epoch   300, train loss 0.004530, train error 0.00,  test loss 3.069808, test error 49.92
# Epoch   400, train loss 0.002911, train error 0.00,  test loss 3.247038, test error 50.00
# Epoch   500, train loss 0.002101, train error 0.00,  test loss 3.379907, test error 50.17
# Epoch   600, train loss 0.001627, train error 0.00,  test loss 3.483733, test error 50.42
# Epoch   700, train loss 0.001317, train error 0.00,  test loss 3.568455, test error 50.33
# Epoch   800, train loss 0.001100, train error 0.00,  test loss 3.640889, test error 50.42
# Epoch   900, train loss 0.000940, train error 0.00,  test loss 3.705412, test error 50.53
# Training model with 140 hidden variables
# Epoch     0, train loss 1.942698, train error 70.43,  test loss 1.878523, test error 73.38
# Epoch   100, train loss 0.038093, train error 0.00,  test loss 2.139275, test error 49.85
# Epoch   200, train loss 0.007995, train error 0.00,  test loss 2.610914, test error 49.85
# Epoch   300, train loss 0.004096, train error 0.00,  test loss 2.841707, test error 49.92
# Epoch   400, train loss 0.002658, train error 0.00,  test loss 2.992464, test error 50.05
# Epoch   500, train loss 0.001932, train error 0.00,  test loss 3.104377, test error 50.00
# Epoch   600, train loss 0.001502, train error 0.00,  test loss 3.193635, test error 50.15
# Epoch   700, train loss 0.001219, train error 0.00,  test loss 3.266751, test error 50.05
# Epoch   800, train loss 0.001020, train error 0.00,  test loss 3.329535, test error 50.08
# Epoch   900, train loss 0.000874, train error 0.00,  test loss 3.383889, test error 50.08
# Training model with 160 hidden variables
# Epoch     0, train loss 1.955121, train error 72.97,  test loss 1.876838, test error 72.70
# Epoch   100, train loss 0.029045, train error 0.00,  test loss 2.098504, test error 48.75
# Epoch   200, train loss 0.007278, train error 0.00,  test loss 2.511726, test error 48.28
# Epoch   300, train loss 0.003821, train error 0.00,  test loss 2.712400, test error 48.67
# Epoch   400, train loss 0.002503, train error 0.00,  test loss 2.843777, test error 48.50
# Epoch   500, train loss 0.001832, train error 0.00,  test loss 2.942540, test error 48.50
# Epoch   600, train loss 0.001429, train error 0.00,  test loss 3.020499, test error 48.50
# Epoch   700, train loss 0.001164, train error 0.00,  test loss 3.085271, test error 48.45
# Epoch   800, train loss 0.000976, train error 0.00,  test loss 3.141727, test error 48.42
# Epoch   900, train loss 0.000837, train error 0.00,  test loss 3.190588, test error 48.35
# Training model with 180 hidden variables
# Epoch     0, train loss 1.908484, train error 70.32,  test loss 1.843245, test error 73.07
# Epoch   100, train loss 0.023784, train error 0.00,  test loss 2.078326, test error 48.62
# Epoch   200, train loss 0.006478, train error 0.00,  test loss 2.421612, test error 48.65
# Epoch   300, train loss 0.003473, train error 0.00,  test loss 2.599471, test error 48.30
# Epoch   400, train loss 0.002299, train error 0.00,  test loss 2.719832, test error 48.50
# Epoch   500, train loss 0.001693, train error 0.00,  test loss 2.810395, test error 48.42
# Epoch   600, train loss 0.001327, train error 0.00,  test loss 2.883461, test error 48.40
# Epoch   700, train loss 0.001083, train error 0.00,  test loss 2.943899, test error 48.42
# Epoch   800, train loss 0.000911, train error 0.00,  test loss 2.996447, test error 48.58
# Epoch   900, train loss 0.000783, train error 0.00,  test loss 3.041752, test error 48.60
# Training model with 200 hidden variables
# Epoch     0, train loss 1.941075, train error 70.03,  test loss 1.871591, test error 71.82
# Epoch   100, train loss 0.020724, train error 0.00,  test loss 2.047418, test error 49.08
# Epoch   200, train loss 0.005891, train error 0.00,  test loss 2.360671, test error 48.83
# Epoch   300, train loss 0.003216, train error 0.00,  test loss 2.523674, test error 48.95
# Epoch   400, train loss 0.002149, train error 0.00,  test loss 2.633411, test error 49.03
# Epoch   500, train loss 0.001590, train error 0.00,  test loss 2.716926, test error 49.05
# Epoch   600, train loss 0.001251, train error 0.00,  test loss 2.783610, test error 49.03
# Epoch   700, train loss 0.001023, train error 0.00,  test loss 2.839254, test error 49.12
# Epoch   800, train loss 0.000862, train error 0.00,  test loss 2.886435, test error 49.12
# Epoch   900, train loss 0.000742, train error 0.00,  test loss 2.928873, test error 49.12
# Training model with 250 hidden variables
# Epoch     0, train loss 1.901357, train error 69.45,  test loss 1.798687, test error 69.30
# Epoch   100, train loss 0.016931, train error 0.00,  test loss 1.939503, test error 47.80
# Epoch   200, train loss 0.005326, train error 0.00,  test loss 2.191236, test error 47.45
# Epoch   300, train loss 0.002972, train error 0.00,  test loss 2.325692, test error 47.40
# Epoch   400, train loss 0.002008, train error 0.00,  test loss 2.417291, test error 47.47
# Epoch   500, train loss 0.001495, train error 0.00,  test loss 2.486660, test error 47.33
# Epoch   600, train loss 0.001180, train error 0.00,  test loss 2.542721, test error 47.28
# Epoch   700, train loss 0.000969, train error 0.00,  test loss 2.589730, test error 47.28
# Epoch   800, train loss 0.000818, train error 0.00,  test loss 2.630294, test error 47.33
# Epoch   900, train loss 0.000706, train error 0.00,  test loss 2.665521, test error 47.28
# Training model with 300 hidden variables
# Epoch     0, train loss 1.867884, train error 67.78,  test loss 1.793631, test error 70.30
# Epoch   100, train loss 0.014341, train error 0.00,  test loss 1.877656, test error 46.03
# Epoch   200, train loss 0.004764, train error 0.00,  test loss 2.101164, test error 45.85
# Epoch   300, train loss 0.002697, train error 0.00,  test loss 2.223186, test error 45.95
# Epoch   400, train loss 0.001839, train error 0.00,  test loss 2.305954, test error 45.80
# Epoch   500, train loss 0.001377, train error 0.00,  test loss 2.370760, test error 45.88
# Epoch   600, train loss 0.001092, train error 0.00,  test loss 2.422508, test error 45.75
# Epoch   700, train loss 0.000899, train error 0.00,  test loss 2.466289, test error 45.75
# Epoch   800, train loss 0.000761, train error 0.00,  test loss 2.503623, test error 45.70
# Epoch   900, train loss 0.000658, train error 0.00,  test loss 2.536803, test error 45.80
# Training model with 400 hidden variables
# Epoch     0, train loss 1.830571, train error 65.88,  test loss 1.756900, test error 68.53
# Epoch   100, train loss 0.011801, train error 0.00,  test loss 1.764569, test error 45.35
# Epoch   200, train loss 0.004186, train error 0.00,  test loss 1.939237, test error 45.30
# Epoch   300, train loss 0.002421, train error 0.00,  test loss 2.037904, test error 45.30
# Epoch   400, train loss 0.001667, train error 0.00,  test loss 2.106987, test error 45.25
# Epoch   500, train loss 0.001256, train error 0.00,  test loss 2.159683, test error 45.38
# Epoch   600, train loss 0.000999, train error 0.00,  test loss 2.202167, test error 45.28
# Epoch   700, train loss 0.000826, train error 0.00,  test loss 2.237840, test error 45.25
# Epoch   800, train loss 0.000701, train error 0.00,  test loss 2.269161, test error 45.25
# Epoch   900, train loss 0.000607, train error 0.00,  test loss 2.296252, test error 45.17

# %%
import matplotlib.pyplot as plt
import numpy as np

# Assuming data['y'] is available and contains the training examples
num_training_examples = len(data['y'])

# Find the index where total_weights_all is closest to num_training_examples
closest_index = np.argmin(np.abs(np.array(total_weights_all) - num_training_examples))

# Get the corresponding value of hidden variables
hidden_variable_at_num_training_examples = hidden_variables[closest_index]

# Plot the results
fig, ax = plt.subplots()
ax.plot(hidden_variables, errors_train_all, 'r-', label='train')
ax.plot(hidden_variables, errors_test_all, 'b-', label='test')

# Add a vertical line at the point where total weights equal the number of training examples
ax.axvline(x=hidden_variable_at_num_training_examples, color='g', linestyle='--', label='N(weights) = N(train)')

ax.set_ylim(0, 100)
ax.set_xlabel('No. hidden variables')
ax.set_ylabel('Error')
ax.legend()
plt.show()
