# %% [markdown]
# <a href="https://colab.research.google.com/github/Mobo140/Research-Physics-ML-Python-/blob/master/Notebooks/Chap10/10_2_Convolution_for_MNIST_1D.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Notebook 10.2: Convolution for MNIST-1D**
#
# This notebook investigates a 1D convolutional network for MNIST-1D as in figure 10.7 and 10.8a.
#
# Work through the cells below, running each cell in turn. In various places you will see the words "TODO". Follow the instructions at these places and make predictions about what is going to happen or write code to complete the functions.
#
# Contact me at udlbookmail@gmail.com if you find any mistakes or have any suggestions.

# %%
# Run this if you're in a Colab to install MNIST 1D repository
# !pip install git+https://github.com/greydanus/mnist1d
# Out:
# Collecting git+https://github.com/greydanus/mnist1d
#   Cloning https://github.com/greydanus/mnist1d to /tmp/pip-req-build-wt7te0s6
#   Running command git clone --filter=blob:none --quiet https://github.com/greydanus/mnist1d /tmp/pip-req-build-wt7te0s6
#   Resolved https://github.com/greydanus/mnist1d to commit 7878d96082abd200c546a07a4101fa90b30fdf7e
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (2.32.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (2.0.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (3.10.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (1.16.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (2.9.0.post0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (2025.10.5)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib->mnist1d==0.0.2.post16) (1.17.0)
# Building wheels for collected packages: mnist1d
#   Building wheel for mnist1d (pyproject.toml) ... done
#   Created wheel for mnist1d: filename=mnist1d-0.0.2.post16-py3-none-any.whl size=14665 sha256=f961ede09b33a5aa7dd3db462aee513bb8d63564a44acc4cb9f1ce8b80ea86ac
#   Stored in directory: /tmp/pip-ephem-wheel-cache-ycjsr7l4/wheels/18/40/b6/29381fee9b4c80fdbc304d52bb065a7286bbcca5ca2b8737c0
# Successfully built mnist1d
# Installing collected packages: mnist1d
# Successfully installed mnist1d-0.0.2.post16

# %%
import numpy as np
import os
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import matplotlib.pyplot as plt
import mnist1d
import random

# %%
args = mnist1d.data.get_dataset_args()
data = mnist1d.data.get_dataset(args, path='./mnist1d_data.pkl', download=False, regenerate=False)

# The training and test input and outputs are in
# data['x'], data['y'], data['x_test'], and data['y_test']
print("Examples in training set: {}".format(len(data['y'])))
print("Examples in test set: {}".format(len(data['y_test'])))
print("Length of each example: {}".format(data['x'].shape[-1]))
# Out:
# Did or could not load data from ./mnist1d_data.pkl. Rebuilding dataset...
# Examples in training set: 4000
# Examples in test set: 1000
# Length of each example: 40

# %%
# Load in the data
train_data_x = data['x'].transpose()
train_data_y = data['y']
val_data_x = data['x_test'].transpose()
val_data_y = data['y_test']
# Print out sizes
print("Train data: %d examples (columns), each of which has %d dimensions (rows)"%((train_data_x.shape[1],train_data_x.shape[0])))
print("Validation data: %d examples (columns), each of which has %d dimensions (rows)"%((val_data_x.shape[1],val_data_x.shape[0])))
# Out:
# Train data: 4000 examples (columns), each of which has 40 dimensions (rows)
# Validation data: 1000 examples (columns), each of which has 40 dimensions (rows)

# %% [markdown]
# Define the network

# %%
# There are 40 input dimensions and 10 output dimensions for this data
# The inputs correspond to the 40 offsets in the MNIST1D template.
D_i = 40
# The outputs correspond to the 10 digits
D_o = 10

# TODO Create a model with the following layers
# 1. Convolutional layer, (input=length 40 and 1 channel, kernel size 3, stride 2, padding="valid", 15 output channels )
# 2. ReLU
# 3. Convolutional layer, (input=length 19 and 15 channels, kernel size 3, stride 2, padding="valid", 15 output channels )
# 4. ReLU
# 5. Convolutional layer, (input=length 9 and 15 channels, kernel size 3, stride 2, padding="valid", 15 output channels)
# 6. ReLU
# 7. Flatten (converts 4x15) to length 60
# 8. Linear layer (input size = 60, output size = 10)
# References:
# https://pytorch.org/docs/1.13/generated/torch.nn.Conv1d.html?highlight=conv1d#torch.nn.Conv1d
# https://pytorch.org/docs/stable/generated/torch.nn.Flatten.html
# https://pytorch.org/docs/1.13/generated/torch.nn.Linear.html?highlight=linear#torch.nn.Linear

# NOTE THAT THE CONVOLUTIONAL LAYERS NEED TO TAKE THE NUMBER OF INPUT CHANNELS AS A PARAMETER
# AND NOT THE INPUT SIZE.

# Replace the following function:
model = nn.Sequential(
  nn.Conv1d(in_channels=1, kernel_size=3, stride=2, out_channels=15),
  nn.ReLU(),
  nn.Conv1d(in_channels=15, kernel_size=3, stride=2, out_channels=15),
  nn.ReLU(),
  nn.Conv1d(in_channels=15, kernel_size=3, stride=2, out_channels=15),
  nn.ReLU(),
  nn.Flatten(),
  nn.Linear(in_features=60, out_features=D_o),
)

# %%
# He initialization of weights
def weights_init(layer_in):
  if isinstance(layer_in, nn.Linear):
    nn.init.kaiming_uniform_(layer_in.weight)
    layer_in.bias.data.fill_(0.0)

# %%
# choose cross entropy loss function (equation 5.24 in the loss notes)
loss_function = nn.CrossEntropyLoss()
# construct SGD optimizer and initialize learning rate and momentum
optimizer = torch.optim.SGD(model.parameters(), lr = 0.05, momentum=0.9)
# object that decreases learning rate by half every 20 epochs
scheduler = StepLR(optimizer, step_size=20, gamma=0.5)
# create 100 dummy data points and store in data loader class
x_train = torch.tensor(train_data_x.transpose().astype('float32'))
y_train = torch.tensor(train_data_y.astype('long')).long()
x_val= torch.tensor(val_data_x.transpose().astype('float32'))
y_val = torch.tensor(val_data_y.astype('long')).long()

# load the data into a class that creates the batches
data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

# Initialize model weights
model.apply(weights_init)

# loop over the dataset n_epoch times
n_epoch = 100
# store the loss and the % correct at each epoch
losses_train = np.zeros((n_epoch))
errors_train = np.zeros((n_epoch))
losses_val = np.zeros((n_epoch))
errors_val = np.zeros((n_epoch))

for epoch in range(n_epoch):
  # loop over batches
  for i, data in enumerate(data_loader):
    # retrieve inputs and labels for this batch
    x_batch, y_batch = data
    # zero the parameter gradients
    optimizer.zero_grad()
    # forward pass -- calculate model output
    pred = model(x_batch[:,None,:])
    # compute the loss
    loss = loss_function(pred, y_batch)
    # backward pass
    loss.backward()
    # SGD update
    optimizer.step()

  # Run whole dataset to get statistics -- normally wouldn't do this
  pred_train = model(x_train[:,None,:])
  pred_val = model(x_val[:,None,:])
  _, predicted_train_class = torch.max(pred_train.data, 1)
  _, predicted_val_class = torch.max(pred_val.data, 1)
  errors_train[epoch] = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
  errors_val[epoch]= 100 - 100 * (predicted_val_class == y_val).float().sum() / len(y_val)
  losses_train[epoch] = loss_function(pred_train, y_train).item()
  losses_val[epoch]= loss_function(pred_val, y_val).item()
  print(f'Epoch {epoch:5d}, train loss {losses_train[epoch]:.6f}, train error {errors_train[epoch]:3.2f},  val loss {losses_val[epoch]:.6f}, percent error {errors_val[epoch]:3.2f}')

  # tell scheduler to consider updating learning rate
  scheduler.step()

# Plot the results
fig, ax = plt.subplots()
ax.plot(errors_train,'r-',label='train')
ax.plot(errors_val,'b-',label='validation')
ax.set_ylim(0,100); ax.set_xlim(0,n_epoch)
ax.set_xlabel('Epoch'); ax.set_ylabel('Error')
ax.set_title('Part I: Validation Result %3.2f'%(errors_val[-1]))
ax.legend()
plt.show()
# Out:
# Epoch     0, train loss 2.268984, train error 83.22,  val loss 2.275607, percent error 85.60
# Epoch     1, train loss 1.776332, train error 70.80,  val loss 1.806164, percent error 74.70
# Epoch     2, train loss 1.436685, train error 55.97,  val loss 1.457180, percent error 60.10
# Epoch     3, train loss 1.389689, train error 56.58,  val loss 1.411240, percent error 58.90
# Epoch     4, train loss 1.274359, train error 51.85,  val loss 1.295147, percent error 53.60
# Epoch     5, train loss 1.210596, train error 50.58,  val loss 1.243880, percent error 55.20
# Epoch     6, train loss 1.083257, train error 43.05,  val loss 1.121802, percent error 45.00
# Epoch     7, train loss 0.973340, train error 40.38,  val loss 1.018233, percent error 43.00
# Epoch     8, train loss 0.907642, train error 36.53,  val loss 0.965547, percent error 39.30
# Epoch     9, train loss 0.789053, train error 31.53,  val loss 0.831900, percent error 33.10
# Epoch    10, train loss 0.709246, train error 28.20,  val loss 0.758009, percent error 31.30
# Epoch    11, train loss 0.668166, train error 24.35,  val loss 0.741460, percent error 25.40
# Epoch    12, train loss 0.580531, train error 22.05,  val loss 0.654410, percent error 25.30
# Epoch    13, train loss 0.479107, train error 18.03,  val loss 0.540984, percent error 21.20
# Epoch    14, train loss 0.432782, train error 16.78,  val loss 0.521605, percent error 19.60
# Epoch    15, train loss 0.367359, train error 13.43,  val loss 0.464751, percent error 16.40
# Epoch    16, train loss 0.343677, train error 12.47,  val loss 0.455973, percent error 16.20
# Epoch    17, train loss 0.275155, train error 9.93,  val loss 0.410791, percent error 15.00
# Epoch    18, train loss 0.275377, train error 9.90,  val loss 0.419854, percent error 14.80
# Epoch    19, train loss 0.217239, train error 7.47,  val loss 0.382733, percent error 12.90
# Epoch    20, train loss 0.142682, train error 4.78,  val loss 0.309178, percent error 9.90
# Epoch    21, train loss 0.130066, train error 4.07,  val loss 0.308281, percent error 9.80
# Epoch    22, train loss 0.151462, train error 5.20,  val loss 0.352301, percent error 11.70
# Epoch    23, train loss 0.122903, train error 4.15,  val loss 0.313985, percent error 9.70
# Epoch    24, train loss 0.108800, train error 3.22,  val loss 0.331202, percent error 9.90
# Epoch    25, train loss 0.105345, train error 3.28,  val loss 0.314089, percent error 9.60
# Epoch    26, train loss 0.103900, train error 3.55,  val loss 0.307776, percent error 9.10
# Epoch    27, train loss 0.093718, train error 2.97,  val loss 0.321300, percent error 9.80
# Epoch    28, train loss 0.087987, train error 2.65,  val loss 0.327451, percent error 8.90
# Epoch    29, train loss 0.112325, train error 3.97,  val loss 0.347010, percent error 10.20
# Epoch    30, train loss 0.082261, train error 2.43,  val loss 0.330934, percent error 9.00
# Epoch    31, train loss 0.077459, train error 2.50,  val loss 0.316003, percent error 8.80
# Epoch    32, train loss 0.070960, train error 2.28,  val loss 0.347352, percent error 9.70
# Epoch    33, train loss 0.073308, train error 2.40,  val loss 0.336518, percent error 9.30
# Epoch    34, train loss 0.065778, train error 1.93,  val loss 0.358143, percent error 9.90
# Epoch    35, train loss 0.060140, train error 1.62,  val loss 0.348833, percent error 9.30
# Epoch    36, train loss 0.067636, train error 2.15,  val loss 0.357627, percent error 9.30
# Epoch    37, train loss 0.056654, train error 1.47,  val loss 0.340131, percent error 9.00
# Epoch    38, train loss 0.066090, train error 1.88,  val loss 0.378266, percent error 9.70
# Epoch    39, train loss 0.053474, train error 1.28,  val loss 0.347461, percent error 8.60
# Epoch    40, train loss 0.051900, train error 1.55,  val loss 0.359316, percent error 8.80
# Epoch    41, train loss 0.041039, train error 0.93,  val loss 0.346618, percent error 8.70
# Epoch    42, train loss 0.039592, train error 0.75,  val loss 0.348882, percent error 8.50
# Epoch    43, train loss 0.039171, train error 0.72,  val loss 0.350578, percent error 8.90
# Epoch    44, train loss 0.036718, train error 0.75,  val loss 0.360174, percent error 8.30
# Epoch    45, train loss 0.037772, train error 0.62,  val loss 0.359087, percent error 8.10
# Epoch    46, train loss 0.038747, train error 0.90,  val loss 0.364061, percent error 8.30
# Epoch    47, train loss 0.035096, train error 0.65,  val loss 0.363526, percent error 8.40
# Epoch    48, train loss 0.035704, train error 0.85,  val loss 0.358860, percent error 8.60
# Epoch    49, train loss 0.032801, train error 0.57,  val loss 0.371311, percent error 8.70
# Epoch    50, train loss 0.031671, train error 0.53,  val loss 0.376107, percent error 9.00
# Epoch    51, train loss 0.030845, train error 0.45,  val loss 0.387213, percent error 9.00
# Epoch    52, train loss 0.030717, train error 0.35,  val loss 0.387254, percent error 9.20
# Epoch    53, train loss 0.032736, train error 0.60,  val loss 0.376923, percent error 8.30
# Epoch    54, train loss 0.030392, train error 0.55,  val loss 0.385942, percent error 8.70
# Epoch    55, train loss 0.029000, train error 0.40,  val loss 0.388477, percent error 8.90
# Epoch    56, train loss 0.029267, train error 0.45,  val loss 0.396324, percent error 8.60
# Epoch    57, train loss 0.027794, train error 0.32,  val loss 0.395936, percent error 8.90
# Epoch    58, train loss 0.026358, train error 0.20,  val loss 0.400815, percent error 8.80
# Epoch    59, train loss 0.027085, train error 0.30,  val loss 0.409706, percent error 9.20
# Epoch    60, train loss 0.024981, train error 0.25,  val loss 0.395135, percent error 8.90
# Epoch    61, train loss 0.023646, train error 0.25,  val loss 0.402536, percent error 8.80
# Epoch    62, train loss 0.022964, train error 0.22,  val loss 0.396435, percent error 8.80
# Epoch    63, train loss 0.022624, train error 0.22,  val loss 0.399730, percent error 8.60
# Epoch    64, train loss 0.022988, train error 0.22,  val loss 0.392765, percent error 8.60
# Epoch    65, train loss 0.021888, train error 0.18,  val loss 0.402366, percent error 8.90
# Epoch    66, train loss 0.021908, train error 0.18,  val loss 0.411764, percent error 9.00
# Epoch    67, train loss 0.021662, train error 0.18,  val loss 0.408409, percent error 9.10
# Epoch    68, train loss 0.021344, train error 0.25,  val loss 0.408311, percent error 8.80
# Epoch    69, train loss 0.021017, train error 0.20,  val loss 0.410294, percent error 8.80
# Epoch    70, train loss 0.021415, train error 0.22,  val loss 0.408153, percent error 8.70
# Epoch    71, train loss 0.020406, train error 0.18,  val loss 0.407401, percent error 8.80
# Epoch    72, train loss 0.020948, train error 0.20,  val loss 0.415715, percent error 9.20
# Epoch    73, train loss 0.020150, train error 0.18,  val loss 0.416260, percent error 9.10
# Epoch    74, train loss 0.020417, train error 0.22,  val loss 0.415598, percent error 8.60
# Epoch    75, train loss 0.019452, train error 0.18,  val loss 0.421917, percent error 9.10
# Epoch    76, train loss 0.019660, train error 0.18,  val loss 0.425716, percent error 9.30
# Epoch    77, train loss 0.020563, train error 0.15,  val loss 0.425300, percent error 8.90
# Epoch    78, train loss 0.019118, train error 0.15,  val loss 0.429772, percent error 9.30
# Epoch    79, train loss 0.019044, train error 0.18,  val loss 0.422851, percent error 9.10
# Epoch    80, train loss 0.018420, train error 0.15,  val loss 0.423978, percent error 9.10
# Epoch    81, train loss 0.018401, train error 0.15,  val loss 0.424506, percent error 8.90
# Epoch    82, train loss 0.018164, train error 0.18,  val loss 0.426244, percent error 9.10
# Epoch    83, train loss 0.018060, train error 0.15,  val loss 0.425466, percent error 8.80
# Epoch    84, train loss 0.017948, train error 0.15,  val loss 0.427264, percent error 9.00
# Epoch    85, train loss 0.017876, train error 0.15,  val loss 0.426979, percent error 9.10
# Epoch    86, train loss 0.017893, train error 0.18,  val loss 0.430127, percent error 9.20
# Epoch    87, train loss 0.017837, train error 0.15,  val loss 0.427559, percent error 9.10
# Epoch    88, train loss 0.017850, train error 0.18,  val loss 0.431319, percent error 8.90
# Epoch    89, train loss 0.017753, train error 0.15,  val loss 0.430966, percent error 8.90
# Epoch    90, train loss 0.017352, train error 0.15,  val loss 0.432750, percent error 9.10
# Epoch    91, train loss 0.017443, train error 0.15,  val loss 0.434752, percent error 9.20
# Epoch    92, train loss 0.017254, train error 0.12,  val loss 0.432391, percent error 9.10
# Epoch    93, train loss 0.017041, train error 0.15,  val loss 0.433260, percent error 9.20
# Epoch    94, train loss 0.017625, train error 0.15,  val loss 0.434519, percent error 8.90
# Epoch    95, train loss 0.016933, train error 0.15,  val loss 0.434601, percent error 9.10
# Epoch    96, train loss 0.016785, train error 0.15,  val loss 0.435690, percent error 9.20
# Epoch    97, train loss 0.016808, train error 0.15,  val loss 0.437224, percent error 9.20
# Epoch    98, train loss 0.016772, train error 0.15,  val loss 0.440610, percent error 9.30
# Epoch    99, train loss 0.016810, train error 0.15,  val loss 0.440179, percent error 9.20
